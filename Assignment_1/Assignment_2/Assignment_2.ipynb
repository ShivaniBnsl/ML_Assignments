# %%
#Question 1
import numpy as np
x=np.random.random((10,1))
np.mean(x)
# Out:
# 0.4650871996584156

# %%
#Question 2
import numpy as np
x=np.random.random((20,1))
np.std(x)
# Out:
# 0.26073077265254224

# %%
#Question 3
A=np.random.random((10,20))
B=np.random.random((20,25))
C=np.matmul(A, B)
print(C)
print("*"*40)

print(np.sum(C))
# Out:
# [[6.7197897  4.06209352 6.08920099 4.538419   4.35203396 6.50164651
#   6.84606652 4.82305592 7.52886936 4.82482642 4.89936302 3.66561435
#   4.77476816 6.13835086 4.55085376 5.6281509  4.16663574 5.21279951
#   5.27521441 5.05075388 4.82948317 5.97167247 4.8266994  5.66019839
#   7.09604907]
#  [5.63112138 4.69875014 5.02257662 4.1120994  3.80629525 4.91218262
#   6.05352047 4.18051183 6.49085352 3.90035877 4.39802252 3.6206468
#   3.51122409 5.30116482 4.15373352 4.44665004 3.49289849 4.95936516
#   4.0584779  4.59960034 4.11934668 4.92029916 3.79542863 4.98793797
#   5.154179  ]
#  [5.6975294  3.33766794 5.3770006  3.94229555 4.23141389 5.92369864
#   6.27721351 3.71959835 6.32288159 4.18208798 4.82058631 3.89677073
#   3.68480518 5.30692324 4.32981851 4.0736283  4.70336171 5.11306799
#   4.78117454 5.01702554 4.56961203 6.25453127 4.21944299 5.11732552
#   5.58376811]
#  [6.11052759 4.22550002 5.98750853 4.42144017 3.67746585 5.62888212
# ...

# %%
#Question 4
B= np.random.rand(10,1)

print(B)

def func(y):
    return (1 / (1 + np.exp(-y)))

result = np.apply_along_axis(func, 0, B)

print('*'*50)

print(result)
# Out:
# [[0.25287419]
#  [0.52659569]
#  [0.95776491]
#  [0.77262079]
#  [0.20069386]
#  [0.17468312]
#  [0.47705025]
#  [0.94236195]
#  [0.11508298]
#  [0.22193114]]
# **************************************************
# [[0.56288381]
#  [0.62868876]
#  [0.72267408]
#  [0.68408755]
#  [0.55000573]
#  [0.54356007]
#  [0.61705109]
#  [0.71957651]
#  [0.52873903]
#  [0.55525617]]
