# %%
#Question 1
import pandas as pd
import numpy as np
data = {'Name':['Shivani_Bansal', 'Sheenu_Bansal'], 'Age':[21,21],'Email_id':['shivani1815.cse16@chitkara.edu.in','bsheenu2@gmail.com'],'phone_number':[1234567890,98765432]}
df = pd.DataFrame(data)
print(df)
# Out:
#              Name  Age                           Email_id  phone_number
# 0  Shivani_Bansal   21  shivani1815.cse16@chitkara.edu.in    1234567890
# 1   Sheenu_Bansal   21                 bsheenu2@gmail.com      98765432

# %%
#Question 2
#A
import pandas as pd
df = pd.read_csv(r'C:\Users\DELL\Desktop\python1\weather.csv')

df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#B
df.head(10)
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1   11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2   11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3   11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4   11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
# 5   11/6/2007  Canberra      6.2     16.9       0.0          5.8       8.2
# 6   11/7/2007  Canberra      6.1     18.2       0.2          4.2       8.4
# 7   11/8/2007  Canberra      8.3     17.0       0.0          5.6       4.6
# 8   11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 9  11/10/2007  Canberra      8.4     22.8      16.2          5.4       7.7
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# ...

# %%
#C
print(df.sum())
# Out:
# Date             11/1/200711/2/200711/3/200711/4/200711/5/20071...
# Location         CanberraCanberraCanberraCanberraCanberraCanber...
# MinTemp                                                     2659.2
# MaxTemp                                                     7521.4
# Rainfall                                                     522.8
# Evaporation                                                   1655
# Sunshine                                                    2871.1
# WindGustSpeed                                                14502
# WindSpeed9am                                                  3465
# WindSpeed3pm                                                  6583
# Humidity9am                                                  26365
# Humidity3pm                                                  16294
# Pressure9am                                                 373214
# Pressure3pm                                                 372153
# ...

# %%
print(df.mean())
# Out:
# MinTemp             7.265574
# MaxTemp            20.550273
# Rainfall            1.428415
# Evaporation         4.521858
# Sunshine            7.909366
# WindGustSpeed      39.840659
# WindSpeed9am        9.651811
# WindSpeed3pm       17.986339
# Humidity9am        72.035519
# Humidity3pm        44.519126
# Pressure9am      1019.709016
# Pressure3pm      1016.810383
# Cloud9am            3.890710
# Cloud3pm            4.024590
# Temp9am            12.358470
# Temp3pm            19.230874
# RISK_MM             1.428415
# dtype: float64

# %%
print(df.std())
# Out:
# MinTemp           6.025800
# MaxTemp           6.690516
# Rainfall          4.225800
# Evaporation       2.669383
# Sunshine          3.481517
# WindGustSpeed    13.059807
# WindSpeed9am      7.951929
# WindSpeed3pm      8.856997
# Humidity9am      13.137058
# Humidity3pm      16.850947
# Pressure9am       6.686212
# Pressure3pm       6.469422
# Cloud9am          2.956131
# Cloud3pm          2.666268
# Temp9am           5.630832
# Temp3pm           6.640346
# RISK_MM           4.225800
# dtype: float64

# %%
print(df.describe())
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
print(df.describe(include='all'))
# Out:
#              Date  Location     MinTemp     MaxTemp    Rainfall  Evaporation  \
# count         366       366  366.000000  366.000000  366.000000   366.000000
# unique        366         1         NaN         NaN         NaN          NaN
# top     6/28/2008  Canberra         NaN         NaN         NaN          NaN
# freq            1       366         NaN         NaN         NaN          NaN
# mean          NaN       NaN    7.265574   20.550273    1.428415     4.521858
# std           NaN       NaN    6.025800    6.690516    4.225800     2.669383
# min           NaN       NaN   -5.300000    7.600000    0.000000     0.200000
# 25%           NaN       NaN    2.300000   15.025000    0.000000     2.200000
# 50%           NaN       NaN    7.450000   19.650000    0.000000     4.200000
# 75%           NaN       NaN   12.500000   25.500000    0.200000     6.400000
# max           NaN       NaN   20.900000   35.800000   39.800000    13.800000
#
# ...

# %%
#D
df.tail(5)
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 361  10/27/2008  Canberra      9.0     30.7       0.0          7.6      12.1
# 362  10/28/2008  Canberra      7.1     28.4       0.0         11.6      12.7
# 363  10/29/2008  Canberra     12.5     19.9       0.0          8.4       5.3
# 364  10/30/2008  Canberra     12.5     26.9       0.0          5.0       7.1
# 365  10/31/2008  Canberra     12.3     30.2       0.0          6.0      12.6
#
#     WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 361         NNW           76.0        SSE      ...               15
# 362           N           48.0        NNW      ...               22
# 363         ESE           43.0        ENE      ...               47
# 364          NW           46.0        SSW      ...               39
# 365          NW           78.0         NW      ...               13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
#E
w=df.loc[df['Date'] == '11/3/2007']
print(w)
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 2          NW           85.0          N      ...               69
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 2       1009.5       1007.2         8         7     15.4     20.2        Yes
#
#    RISK_MM  RainTomorrow
# 2     39.8           Yes
#
# [1 rows x 24 columns]

# %%
print(w.sum())
# Out:
# Date             11/3/2007
# Location          Canberra
# MinTemp               13.7
# MaxTemp               23.4
# Rainfall               3.6
# Evaporation            5.8
# Sunshine               3.3
# WindGustDir             NW
# WindGustSpeed           85
# WindDir9am               N
# WindDir3pm             NNE
# WindSpeed9am             6
# WindSpeed3pm             6
# Humidity9am             82
# Humidity3pm             69
# Pressure9am         1009.5
# Pressure3pm         1007.2
# Cloud9am                 8
# Cloud3pm                 7
# Temp9am               15.4
# Temp3pm               20.2
# RainToday              Yes
# RISK_MM               39.8
# RainTomorrow           Yes
# dtype: object

# %%
print(w.mean())
# Out:
# MinTemp            13.7
# MaxTemp            23.4
# Rainfall            3.6
# Evaporation         5.8
# Sunshine            3.3
# WindGustSpeed      85.0
# WindSpeed9am        6.0
# WindSpeed3pm        6.0
# Humidity9am        82.0
# Humidity3pm        69.0
# Pressure9am      1009.5
# Pressure3pm      1007.2
# Cloud9am            8.0
# Cloud3pm            7.0
# Temp9am            15.4
# Temp3pm            20.2
# RISK_MM            39.8
# dtype: float64

# %%
print(w.std())
# Out:
# MinTemp         NaN
# MaxTemp         NaN
# Rainfall        NaN
# Evaporation     NaN
# Sunshine        NaN
# WindGustSpeed   NaN
# WindSpeed9am    NaN
# WindSpeed3pm    NaN
# Humidity9am     NaN
# Humidity3pm     NaN
# Pressure9am     NaN
# Pressure3pm     NaN
# Cloud9am        NaN
# Cloud3pm        NaN
# Temp9am         NaN
# Temp3pm         NaN
# RISK_MM         NaN
# dtype: float64
